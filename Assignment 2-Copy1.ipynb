# %%
def xyz (query, api_key, rating, max_output):
    import string
    import random
    import requests
    import json
    
    url="https://maps.googleapis.com/maps/api/place/textsearch/json?query="
    query = query.replace(" ","+")
    url+= query
    url += "&key=" + api_key
    response = requests.get(url)
    if response.status_code != 200:
        print("not working")
    data_string = response.content.decode("utf-8")
    python_data = json.loads(data_string)
    m = python_data
    print (m)
    return m
xyz("restaurants","AIzaSyCVtddNa2zUXQrmKr4RHvKsiP4T8gG8Df4",4.0,20)
#m
# Out:
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}

# %%
    import string
    import random
    import requests
    import json
    
    query="restaurants near Columbia"
    url="https://maps.googleapis.com/maps/api/place/textsearch/json?query="
    query = query.replace(" ","+")
    url+= query
    url += "&key=" + api_key
    response = requests.get(url)
    if response.status_code != 200:
        print("not working")
    data_string = response.content.decode("utf-8")
    python_data = json.loads(data_string)
    m = python_data
    print (m)
# Out:
# {'html_attributions': [], 'next_page_token': 'CpQCCgEAAFUD-FRRyUymcw136X9hnJdlRCUFvHsslYzAYchVb1Hg2--6Kj622JRnO5DWvZtlLAZ7f0aoY0bZAdo-5JAYDnHrmF7Nkg6LlGqRHFJ6-wjItIh_dZFxyom_35gUioZDJZLqdy-NIRfrng_WLo9wC9jwA3F1Tvu1GOmgXhvWSRtI_j-PoNeyCQhtY1YTCqNXztvLvswgr5zcG4Jc8bpSrY-hWzJsypdA_w-udtonJPKFKCg5-zvgZwWRg4TKAtL5AFrlhdDqxE-9UDBTDqcwLdkdlXE0TedLv-dMBekE0nvnTsQqaQzYqmyBhczxlizceUpUKQ0P2xWiZfCDUJo4UR5OkM7ouIiL8Mwn4m8Xx6u7EhDNQq4SIISpvKJkcjk2rsmkGhQxetr__kWG1UG3m14K9BHV-NdQMQ', 'results': [{'formatted_address': '8900 Stanford Blvd, Columbia, MD 21045, USA', 'geometry': {'location': {'lat': 39.1931021, 'lng': -76.81455609999999}, 'viewport': {'northeast': {'lat': 39.19438727989272, 'lng': -76.81327397010726}, 'southwest': {'lat': 39.19168762010728, 'lng': -76.81597362989271}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png', 'id': '3b84c66de8268edf15c065787095ebdb1307fc02', 'name': 'Stanford Grill', 'opening_hours': {'open_now': True}, 'photos': [{'height': 1325
# ...

# %%
n
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CpQCCgEAAFUD-FRRyUymcw136X9hnJdlRCUFvHsslYzAYchVb1Hg2--6Kj622JRnO5DWvZtlLAZ7f0aoY0bZAdo-5JAYDnHrmF7Nkg6LlGqRHFJ6-wjItIh_dZFxyom_35gUioZDJZLqdy-NIRfrng_WLo9wC9jwA3F1Tvu1GOmgXhvWSRtI_j-PoNeyCQhtY1YTCqNXztvLvswgr5zcG4Jc8bpSrY-hWzJsypdA_w-udtonJPKFKCg5-zvgZwWRg4TKAtL5AFrlhdDqxE-9UDBTDqcwLdkdlXE0TedLv-dMBekE0nvnTsQqaQzYqmyBhczxlizceUpUKQ0P2xWiZfCDUJo4UR5OkM7ouIiL8Mwn4m8Xx6u7EhDNQq4SIISpvKJkcjk2rsmkGhQxetr__kWG1UG3m14K9BHV-NdQMQ',
#  'results': [{'formatted_address': '8900 Stanford Blvd, Columbia, MD 21045, USA',
#    'geometry': {'location': {'lat': 39.1931021, 'lng': -76.81455609999999},
#     'viewport': {'northeast': {'lat': 39.19438727989272,
#       'lng': -76.81327397010726},
#      'southwest': {'lat': 39.19168762010728, 'lng': -76.81597362989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '3b84c66de8268edf15c065787095ebdb1307fc02',
#    'name': 'Stanford Grill',
# ...

# %%
_list = list()
for i in m.keys():
    _list.append(i)
print(_list)
# Out:
# ['html_attributions', 'next_page_token', 'results', 'status']

# %%
_list = list()
for i in n["results"]:
    item = i.get('name')
    print(item)
    #z=m["results"][i]
    #_list.append(z)
#print(_list)
# Out:
# Stanford Grill
# The Ale House Columbia
# Royal Taj Restaurant
# MISSION BBQ
# The Iron Bridge Wine Company
# Rudy's Mediterranean Grill & Bar
# Sushi King
# Clyde's of Columbia
# Chutney Indian Restaurant
# The Kings Contrivance
# The Corner Stable
# Maggiano's Little Italy
# Tino's Italian Bistro
# Seasons 52
# Sushi Sono
# Nalley Fresh
# The Turn House
# An Loi
# CAVA
# HomeSlyce Columbia

# %%
_dict = {}
for i in m["results"]:
    items = list(m.results())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-288a296e6cbd> in <module>()
#       1 _dict = {}
#       2 for i in m["results"]:
# ----> 3     items = list(m.results())
#
# AttributeError: 'dict' object has no attribute 'results'

# %%
_dict = {}
keep_keys = set()
for i in n["results"]:
    keep_keys = ["name","formatted_address"]
    remove_keys=i.keys()-keep_keys
    for k in remove_keys:
        del i[k]

o=n["results"]
mylist=[]
for i in o:
    mylist.append(i.items())
print(mylist)
# Out:
# [dict_items([('formatted_address', '8900 Stanford Blvd, Columbia, MD 21045, USA'), ('name', 'Stanford Grill')]), dict_items([('formatted_address', '6480 Dobbin Center Way, Columbia, MD 21045, USA'), ('name', 'The Ale House Columbia')]), dict_items([('formatted_address', '8335 Benson Dr, Columbia, MD 21045, USA'), ('name', 'Royal Taj Restaurant')]), dict_items([('formatted_address', '6270 Columbia Crossing Cir, Columbia, MD 21045, USA'), ('name', 'MISSION BBQ')]), dict_items([('formatted_address', '10435 MD-108, Columbia, MD 21044, USA'), ('name', 'The Iron Bridge Wine Company')]), dict_items([('formatted_address', '7185 Columbia Gateway Dr, Columbia, MD 21046, USA'), ('name', "Rudy's Mediterranean Grill & Bar")]), dict_items([('formatted_address', '6490 Dobbin Rd, Columbia, MD 21045, USA'), ('name', 'Sushi King')]), dict_items([('formatted_address', '10221 Wincopin Cir, Columbia, MD 21044, USA'), ('name', "Clyde's of Columbia")]), dict_items([('formatted_address', '9400 Snowden River
# ...

# %%
o
# Out:
# [{'formatted_address': '8900 Stanford Blvd, Columbia, MD 21045, USA',
#   'name': 'Stanford Grill'},
#  {'formatted_address': '6480 Dobbin Center Way, Columbia, MD 21045, USA',
#   'name': 'The Ale House Columbia'},
#  {'formatted_address': '8335 Benson Dr, Columbia, MD 21045, USA',
#   'name': 'Royal Taj Restaurant'},
#  {'formatted_address': '6270 Columbia Crossing Cir, Columbia, MD 21045, USA',
#   'name': 'MISSION BBQ'},
#  {'formatted_address': '10435 MD-108, Columbia, MD 21044, USA',
#   'name': 'The Iron Bridge Wine Company'},
#  {'formatted_address': '7185 Columbia Gateway Dr, Columbia, MD 21046, USA',
#   'name': "Rudy's Mediterranean Grill & Bar"},
#  {'formatted_address': '6490 Dobbin Rd, Columbia, MD 21045, USA',
#   'name': 'Sushi King'},
#  {'formatted_address': '10221 Wincopin Cir, Columbia, MD 21044, USA',
#   'name': "Clyde's of Columbia"},
#  {'formatted_address': '9400 Snowden River Pkwy, Columbia, MD 21045, USA',
#   'name': 'Chutney Indian Restaurant'},
# ...

# %%
n["results"].keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-b50784d8c341> in <module>()
# ----> 1 n["results"].keys()
#
# AttributeError: 'list' object has no attribute 'keys'

# %% [markdown]
# Part 2: Pagination

# %%
#api_key =  my_api;
radius = 0
location = 0
query = 'restaurants+near+Columbia+University';min_rating=4.0;max_results=40
origin_url = 'https://maps.googleapis.com/maps/api/place/textsearch/json?'
api_url = origin_url + 'query='
url = api_url+query+"&key="+api_key
if radius:
    url+="&radius="+str(radius)
if location:
    url+="&location="+str(location)
import requests
try:
    response = requests.get(url)
    if not response.status_code == 200:
        print("HTTP error",response.status_code)
    else:
        try:
            response_data = response.json()
        except:
            list()
except:
    list()
    
response_data['next_page_token']
count = 0
while "next_page_token" in response_data:
    count +=1
    if count >25:
        break
    print(2)
    pagetoken = response_data['next_page_token']
    new_url = origin_url  + "&pagetoken=" + str(pagetoken)+ '&key=' + str(api_key)
    response = requests.get(new_url)
    print(2.5)
    while response.json().get('status') != 'OK':
                from time import sleep
                from random import random
                sleep(random())
                response = requests.get(new_url)
                print(2.7)
                print(response.json().get('status'))
    
# and the output is: 
2
2.5
2.7
INVALID_REQUEST
2.7
OK
2
2.5
2
2.5
2
2.5
2
2.5
2
2.5
2
2.5
2
2.5
2
2.5
# Out:
# 2
# 2.5
# 2.7
# INVALID_REQUEST
# 2.7
# OK
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# 2
# 2.5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-515f110e5192> in <module>()
#      46 2.5
#      47 2.7
# ---> 48 INVALID_REQUEST
#      49 2.7
#      50 OK
#
# NameError: name 'INVALID_REQUEST' is not defined
